# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/master.csv")
df = pd.DataFrame(df)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    disasterNumber  states_affected  counties_affected incident_type  \
# 0            1239                1                255  Severe Storm
# 1            1257                1                 43         Flood
# 2            1260                1                 33  Severe Storm
# 3            1261                1                 12  Severe Storm
# 4            1262                1                 24  Severe Storm
#
#             declaration_date             incident_begin  \
# 0  1998-08-26 00:00:00+00:00  1998-08-22 00:00:00+00:00
# 1  1998-10-21 00:00:00+00:00  1998-10-17 00:00:00+00:00
# 2  1999-01-15 00:00:00+00:00  1998-12-23 00:00:00+00:00
# 3  1999-01-15 00:00:00+00:00  1998-12-23 00:00:00+00:00
# 4  1999-01-19 00:00:00+00:00  1999-01-17 00:00:00+00:00
#
#                 incident_end  ih_declared  ia_declared  pa_declared  \
# 0  1998-08-31 00:00:00+00:00        False         True         True
# 1  1998-11-15 00:00:00+00:00        False         True         True
# ...

# %%
# median_duration = df['incident_duration_days'].median()

# df['incident_duration_days'] = df['incident_duration_days'].fillna(median_duration)

# print(median_duration)
print(df.shape)
# Out:
# (1765, 32)

# %%
df.isnull().sum()
# Out:
# disasterNumber              0
# states_affected             0
# counties_affected           0
# incident_type               0
# declaration_date            0
# incident_begin              0
# incident_end                0
# ih_declared                 0
# ia_declared                 0
# pa_declared                 0
# hm_declared                 0
# tribal_request              0
# fy_declared                 0
# incident_duration_days      0
# declaration_lag_days        0
# declaration_month           0
# total_recovery_cost         0
# totalAmountIaApproved       0
# project_count               0
# unique_applicants           0
# unique_damage_categories    0
# total_federal_obligated     0
# pa_cat_A                    0
# pa_cat_B                    0
# pa_cat_C                    0
# pa_cat_D                    0
# pa_cat_E                    0
# pa_cat_F                    0
# pa_cat_G                    0
# pa_cat_I                    0
# pa_cat_Z                    0
# ...

# %%
df.to_csv("../data/processed/preprocessed_master.csv", index=False)
